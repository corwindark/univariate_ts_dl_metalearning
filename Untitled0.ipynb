# %% [markdown]
# <a href="https://colab.research.google.com/github/corwindark/univariate_ts_dl_metalearning/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# TENSORFLOW
import tensorflow as tf
print("TENSORFLOW VERSION:",tf.__version__)

# PYTORCH
import torch
print("PYTORCH VERSION:",torch.__version__)

# KERAS
import keras;
print("KERAS VERSION:",keras.__version__)
# Out:
# TENSORFLOW VERSION: 2.15.0
# PYTORCH VERSION: 2.1.0+cu121
# KERAS VERSION: 2.15.0

# %%
print(torch.cuda.is_available())
# Out:
# True

# %%
# GET SYSTEM INFO
# code modified from: https://stackoverflow.com/questions/110362/how-can-i-find-the-current-os-in-python

import platform
import multiprocessing
import sys
import psutil

def linux_distribution():
  try:
    return platform.linux_distribution()
  except:
    return "N/A"

def dist():
  try:
    return platform.dist()
  except:
    return "N/A"

num_cores=multiprocessing.cpu_count()

print("""
Python version: %s
dist: %s
num_cores: %s
linux_distribution: %s
system: %s
machine: %s
platform: %s
uname: %s
version: %s
RAM: %s
""" % (
sys.version.split('\n'),
str(dist()),
num_cores,
linux_distribution(),
platform.system(),
platform.machine(),
platform.platform(),
platform.uname(),
platform.version(),
psutil.virtual_memory().total*10**(-9.)
))

# print('GPU name: ', tf.config.experimental.list_physical_devices('GPU'))
# Out:
# Python version: ['3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]']
# dist: N/A
# num_cores: 2
# linux_distribution: N/A
# system: Linux
# machine: x86_64
# platform: Linux-6.1.58+-x86_64-with-glibc2.35
# uname: uname_result(system='Linux', node='552b496f7958', release='6.1.58+', version='#1 SMP PREEMPT_DYNAMIC Sat Nov 18 15:31:17 UTC 2023', machine='x86_64')
# version: #1 SMP PREEMPT_DYNAMIC Sat Nov 18 15:31:17 UTC 2023
# RAM: 13.60945152

# %%
torch.cuda.device_count()
torch.cuda.get_device_properties(0).total_memory
# Out:
# 15835660288

# %%
import yfinance as yf
import pandas as pd
import seaborn as sns
import matplotlib as plt
from sklearn.model_selection import TimeSeriesSplit
from datetime import datetime
import matplotlib.pyplot as plt

pd.options.mode.chained_assignment = None

# %%
import subprocess
import sys

subprocess.check_call([sys.executable, "-m", "pip", "install", "statsforecast"])
# Out:
# 0

# %%
data = yf.download('SPY','2022-06-01','2023-09-30', interval ="60m")
# %matplotlib inline

data['Adj Close'].plot()
plt.ion()
print(data)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                            Open        High         Low       Close  \
# Datetime
# 2022-06-01 09:30:00  415.170013  416.239990  410.239990  410.269989
# 2022-06-01 10:30:00  410.265015  411.049988  407.970001  408.779999
# 2022-06-01 11:30:00  408.778809  409.070007  407.059998  407.540009
# 2022-06-01 12:30:00  407.549988  409.589996  406.929993  409.200012
# 2022-06-01 13:30:00  409.250000  412.100006  408.809998  411.679993
# ...                         ...         ...         ...         ...
# 2023-09-29 11:30:00  430.000000  430.209503  428.635010  429.410004
# 2023-09-29 12:30:00  429.429993  429.595001  426.500000  427.500000
# 2023-09-29 13:30:00  427.494995  427.679993  426.010010  426.260010
# 2023-09-29 14:30:00  426.269989  428.470001  425.910004  427.579987
# 2023-09-29 15:30:00  427.589996  428.875000  426.739990  427.410004
#
#                       Adj Close    Volume
# Datetime
# 2022-06-01 09:30:00  410.269989  15543246
# 2022-06-01 10:30:00  408.779999  14071181
# 2022-06-01 11:30:00  407.540009   9087317
# 2022-06-01 12:30:00  409.200012   7867498
# 2022-06-01 13:30:00  411.679993  10583366
# ...                         ...       ...
# 2023-09-29 11:30:00  429.410004   9596312
# 2023-09-29 12:30:00  427.500000  12763406
# 2023-09-29 13:30:00  426.260010  12485095
# 2023-09-29 14:30:00  427.579987  16267060
# 2023-09-29 15:30:00  427.410004  20067751
#
# [2335 rows x 6 columns]

# %%
data.reset_index(inplace = True)

# %%
print(data.head())
# Out:
#              Datetime        Open        High         Low       Close  \
# 0 2022-06-01 09:30:00  415.170013  416.239990  410.239990  410.269989
# 1 2022-06-01 10:30:00  410.265015  411.049988  407.970001  408.779999
# 2 2022-06-01 11:30:00  408.778809  409.070007  407.059998  407.540009
# 3 2022-06-01 12:30:00  407.549988  409.589996  406.929993  409.200012
# 4 2022-06-01 13:30:00  409.250000  412.100006  408.809998  411.679993
#
#     Adj Close    Volume
# 0  410.269989  15543246
# 1  408.779999  14071181
# 2  407.540009   9087317
# 3  409.200012   7867498
# 4  411.679993  10583366

# %%
train_size = 2000

data_train = data[:train_size]
data_test = data[train_size:]

test_size = len(data_test)


data_test = data_test[["Datetime", "Close"]]
data_train = data_train[["Datetime", "Close"]]

seriesTrain = data_train.set_index('Datetime')
seriesTest = data_test.set_index('Datetime')

# %%
#print(seriesTrain.head())
print(data_test.head())
# Out:
# Empty DataFrame
# Columns: [Datetime, Close]
# Index: []

# %%
# Let's reformat the test data into a dataframe we can add our predictions to

testResultsDF = pd.DataFrame(index = range(test_size))
testResultsDF['Price'] = 0
# Get a clean format for close prices
for i in range(0,test_size):
    testResultsDF['Price'][i] = seriesTest.values[i][0]


# Initialize empty cells for the statistical forecasts
testResultsDF['auto_arima'] = 0
testResultsDF['dyn_theta'] = 0
testResultsDF['auto_ets'] = 0
testResultsDF['complex_smoothing'] = 0

# %%
print(testResultsDF.head())
# Out:
# Empty DataFrame
# Columns: [Price, auto_arima, dyn_theta, auto_ets, complex_smoothing]
# Index: []

# %%
def crossValidation(train, test, window, outputFrame, modelName, predReturnFunction):

    totalPredictions = pd.Series(dtype = 'float64')
    windows = len(test) // window

    predictionIndex = 0

    for i in range(0, windows):
        # debug
        #print("Window: ", i, "Method: ", modelName)

        # How many observations to move forward each frame
        addNum = i * window
        # Combine training data with additional test window
        intermediateData = pd.concat([train, test[:addNum]])
        # Generate prediction of the given window size
        prediction = predReturnFunction(intermediateData, window)
        #print(prediction)
        # Check if we have multiple predictions in the window
        if len(prediction) > 1:
            # Store each predicted value with a loop
            for j in range(0,window):

                # Store in the prediction-comparison frame
                outputFrame[modelName][predictionIndex] = prediction[j]

                # Move to next open spot
                predictionIndex += 1
        else:

            outputFrame[modelName][predictionIndex] = prediction[0]
            predictionIndex += 1

# %%
from statsforecast import StatsForecast
from statsforecast.models import AutoCES, AutoARIMA, AutoETS, DynamicOptimizedTheta
import numpy as np
import time
# Out:
# /usr/local/lib/python3.10/dist-packages/statsforecast/core.py:26: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
def aaPredFunction(dataIn, windowSize):
    model = AutoARIMA()
    fit1 = model.fit(y = np.concatenate(dataIn.to_numpy()))
    prediction = fit1.predict(h = windowSize)
    return prediction.get('mean')


def cesPredFunction(dataIn, windowSize):
    model = AutoCES()
    fit1 = model.fit(y = np.concatenate(dataIn.to_numpy()))
    predictionList = fit1.predict(windowSize)
    return predictionList.get('mean')

def etsPredFunction(dataIn, windowSize):
    model = AutoETS()
    fit1 = model.fit(y = np.concatenate(dataIn.to_numpy()))
    predictionList = fit1.predict(windowSize)
    return predictionList.get('mean')

def dotPredFunction(dataIn, windowSize):
    model = DynamicOptimizedTheta()
    fit1 = model.fit(y = np.concatenate(dataIn.to_numpy()))
    predictionList = fit1.predict(windowSize)
    return predictionList.get('mean')


# Set the number of observations to be included in the test set
test_out_size = 200

tempTest = seriesTest[:test_out_size]

# Auto Arima
crossValidation(seriesTrain, tempTest, 1, testResultsDF, 'auto_arima', aaPredFunction)

crossValidation(seriesTrain, tempTest, 1, testResultsDF, 'complex_smoothing', cesPredFunction)

crossValidation(seriesTrain, tempTest, 1, testResultsDF, 'auto_ets', etsPredFunction)

crossValidation(seriesTrain, tempTest, 1, testResultsDF, 'dyn_theta', dotPredFunction)
# Out:
# <ipython-input-23-d1335f011bb4>:3: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   totalPredictions = pd.Series([])
# Window:  0 Method:  auto_arima
# [454.75469971]
# Window:  1 Method:  auto_arima
# <ipython-input-23-d1335f011bb4>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outputFrame[modelName][predictionIndex] = prediction[0]
# [454.98001099]
# Window:  2 Method:  auto_arima
# [455.375]
# Window:  3 Method:  auto_arima
# [455.98999023]
# Window:  4 Method:  auto_arima
# [456.38000488]
# Window:  5 Method:  auto_arima
# [455.98001099]
# Window:  6 Method:  auto_arima
# [455.42999268]
# Window:  7 Method:  auto_arima
# [454.72000122]
# Window:  8 Method:  auto_arima
# [454.35998535]
# Window:  9 Method:  auto_arima
# [454.63500977]
# Window:  10 Method:  auto_arima
# [454.29000854]
# Window:  11 Method:  auto_arima
# [454.33999634]
# Window:  12 Method:  auto_arima
# [454.50500488]
# Window:  13 Method:  auto_arima
# [455.51000977]
# Window:  14 Method:  auto_arima
# [457.70001221]
# Window:  15 Method:  auto_arima
# [457.70788574]
# Window:  16 Method:  auto_arima
# [458.38009644]
# Window:  17 Method:  auto_arima
# [456.29998779]
# Window:  18 Method:  auto_arima
# [453.93499756]
# Window:  19 Method:  auto_arima
# [452.73999023]
# Window:  20 Method:  auto_arima
# [452.46499634]
# Window:  21 Method:  auto_arima
# [456.3999939]
# Window:  22 Method:  auto_arima
# [457.44000244]
# Window:  23 Method:  auto_arima
# [457.59570312]
# Window:  24 Method:  auto_arima
# [456.1512146]
# Window:  25 Method:  auto_arima
# [456.91000366]
# Window:  26 Method:  auto_arima
# [456.66598511]
# Window:  27 Method:  auto_arima
# [456.91000366]
# Window:  28 Method:  auto_arima
# [457.70001221]
# Window:  29 Method:  auto_arima
# [457.27999878]
# Window:  30 Method:  auto_arima
# [457.20999146]
# Window:  31 Method:  auto_arima
# [456.61871338]
# Window:  32 Method:  auto_arima
# [456.67999268]
# Window:  33 Method:  auto_arima
# [456.68499756]
# Window:  34 Method:  auto_arima
# [457.79000854]
# Window:  35 Method:  auto_arima
# [455.92999268]
# Window:  36 Method:  auto_arima
# [456.25338745]
# Window:  37 Method:  auto_arima
# [455.79000854]
# Window:  38 Method:  auto_arima
# [456.33499146]
# Window:  39 Method:  auto_arima
# [456.58499146]
# Window:  40 Method:  auto_arima
# [456.69000244]
# Window:  41 Method:  auto_arima
# [456.47000122]
# Window:  42 Method:  auto_arima
# [451.95999146]
# Window:  43 Method:  auto_arima
# [451.12008667]
# Window:  44 Method:  auto_arima
# [450.23959351]
# Window:  45 Method:  auto_arima
# [451.10998535]
# Window:  46 Method:  auto_arima
# [450.79501343]
# Window:  47 Method:  auto_arima
# [449.41000366]
# Window:  48 Method:  auto_arima
# [450.14001465]
# Window:  49 Method:  auto_arima
# [447.42001343]
# Window:  50 Method:  auto_arima
# [449.38000488]
# Window:  51 Method:  auto_arima
# [449.67001343]
# Window:  52 Method:  auto_arima
# [450.48001099]
# Window:  53 Method:  auto_arima
# [449.81008911]
# Window:  54 Method:  auto_arima
# [449.23001099]
# Window:  55 Method:  auto_arima
# [448.83999634]
# Window:  56 Method:  auto_arima
# [450.42999268]
# Window:  57 Method:  auto_arima
# [451.54998779]
# Window:  58 Method:  auto_arima
# [452.49880981]
# Window:  59 Method:  auto_arima
# [451.66000366]
# Window:  60 Method:  auto_arima
# [448.19000244]
# Window:  61 Method:  auto_arima
# [447.1098938]
# Window:  62 Method:  auto_arima
# [446.80999756]
# Window:  63 Method:  auto_arima
# [449.63000488]
# Window:  64 Method:  auto_arima
# [448.69000244]
# Window:  65 Method:  auto_arima
# [449.57000732]
# Window:  66 Method:  auto_arima
# [449.64001465]
# Window:  67 Method:  auto_arima
# [449.61999512]
# Window:  68 Method:  auto_arima
# [449.75]
# Window:  69 Method:  auto_arima
# [450.72000122]
# Window:  70 Method:  auto_arima
# [446.19000244]
# Window:  71 Method:  auto_arima
# [446.19000244]
# Window:  72 Method:  auto_arima
# [446.45999146]
# Window:  73 Method:  auto_arima
# [446.93499756]
# Window:  74 Method:  auto_arima
# [447.66598511]
# Window:  75 Method:  auto_arima
# [448.57058716]
# Window:  76 Method:  auto_arima
# [448.75]
# Window:  77 Method:  auto_arima
# [448.47000122]
# Window:  78 Method:  auto_arima
# [446.01998901]
# Window:  79 Method:  auto_arima
# [445.96499634]
# Window:  80 Method:  auto_arima
# [447.41900635]
# Window:  81 Method:  auto_arima
# [448.50500488]
# Window:  82 Method:  auto_arima
# [447.79998779]
# Window:  83 Method:  auto_arima
# [445.76000977]
# Window:  84 Method:  auto_arima
# [450.95001221]
# Window:  85 Method:  auto_arima
# [448.82998657]
# Window:  86 Method:  auto_arima
# [446.8711853]
# Window:  87 Method:  auto_arima
# [446.05999756]
# Window:  88 Method:  auto_arima
# [446.42498779]
# Window:  89 Method:  auto_arima
# [446.22000122]
# Window:  90 Method:  auto_arima
# [445.92001343]
# Window:  91 Method:  auto_arima
# [446.04501343]
# Window:  92 Method:  auto_arima
# [444.57998657]
# Window:  93 Method:  auto_arima
# [445.07681274]
# Window:  94 Method:  auto_arima
# [445.42999268]
# Window:  95 Method:  auto_arima
# [445.6499939]
# Window:  96 Method:  auto_arima
# [445.86999512]
# Window:  97 Method:  auto_arima
# [445.57998657]
# Window:  98 Method:  auto_arima
# [445.89001465]
# Window:  99 Method:  auto_arima
# [447.1499939]
# Window:  100 Method:  auto_arima
# [446.67001343]
# Window:  101 Method:  auto_arima
# [447.32998657]
# Window:  102 Method:  auto_arima
# [446.80999756]
# Window:  103 Method:  auto_arima
# [446.85501099]
# Window:  104 Method:  auto_arima
# [448.1000061]
# Window:  105 Method:  auto_arima
# [444.01998901]
# Window:  106 Method:  auto_arima
# [444.84500122]
# Window:  107 Method:  auto_arima
# [444.66918945]
# Window:  108 Method:  auto_arima
# [444.51501465]
# Window:  109 Method:  auto_arima
# [443.88000488]
# Window:  110 Method:  auto_arima
# [442.66000366]
# Window:  111 Method:  auto_arima
# [442.93978882]
# Window:  112 Method:  auto_arima
# [443.3999939]
# Window:  113 Method:  auto_arima
# [443.52999878]
# Window:  114 Method:  auto_arima
# [441.82000732]
# Window:  115 Method:  auto_arima
# [441.32000732]
# Window:  116 Method:  auto_arima
# [442.61999512]
# Window:  117 Method:  auto_arima
# [440.11999512]
# Window:  118 Method:  auto_arima
# [439.63000488]
# Window:  119 Method:  auto_arima
# [440.1499939]
# Window:  120 Method:  auto_arima
# [439.30999756]
# Window:  121 Method:  auto_arima
# [440.36999512]
# Window:  122 Method:  auto_arima
# [439.30999756]
# Window:  123 Method:  auto_arima
# [438.51998901]
# Window:  124 Method:  auto_arima
# [436.80200195]
# Window:  125 Method:  auto_arima
# [436.26000977]
# Window:  126 Method:  auto_arima
# [433.8500061]
# Window:  127 Method:  auto_arima
# [435.26501465]
# Window:  128 Method:  auto_arima
# [435.70498657]
# Window:  129 Method:  auto_arima
# [435.54998779]
# Window:  130 Method:  auto_arima
# [435.95498657]
# Window:  131 Method:  auto_arima
# [436.14001465]
# Window:  132 Method:  auto_arima
# [436.45999146]
# Window:  133 Method:  auto_arima
# [436.64001465]
# Window:  134 Method:  auto_arima
# [435.99560547]
# Window:  135 Method:  auto_arima
# [436.91000366]
# Window:  136 Method:  auto_arima
# [437.8999939]
# Window:  137 Method:  auto_arima
# [438.34851074]
# Window:  138 Method:  auto_arima
# [439.3999939]
# Window:  139 Method:  auto_arima
# [439.33999634]
# Window:  140 Method:  auto_arima
# [439.57000732]
# Window:  141 Method:  auto_arima
# [439.36999512]
# Window:  142 Method:  auto_arima
# [438.5401001]
# Window:  143 Method:  auto_arima
# [438.23001099]
# Window:  144 Method:  auto_arima
# [438.57998657]
# Window:  145 Method:  auto_arima
# [438.48999023]
# Window:  146 Method:  auto_arima
# [438.1000061]
# Window:  147 Method:  auto_arima
# [440.8999939]
# Window:  148 Method:  auto_arima
# [442.1499939]
# Window:  149 Method:  auto_arima
# [442.07000732]
# Window:  150 Method:  auto_arima
# [443.22000122]
# Window:  151 Method:  auto_arima
# [442.9598999]
# Window:  152 Method:  auto_arima
# [443.20001221]
# Window:  153 Method:  auto_arima
# [442.98001099]
# Window:  154 Method:  auto_arima
# [442.17001343]
# Window:  155 Method:  auto_arima
# [440.67999268]
# Window:  156 Method:  auto_arima
# [440.]
# Window:  157 Method:  auto_arima
# [439.13000488]
# Window:  158 Method:  auto_arima
# [439.15341187]
# Window:  159 Method:  auto_arima
# [438.69000244]
# Window:  160 Method:  auto_arima
# [436.92001343]
# Window:  161 Method:  auto_arima
# [437.58999634]
# Window:  162 Method:  auto_arima
# [438.02999878]
# Window:  163 Method:  auto_arima
# [438.82998657]
# Window:  164 Method:  auto_arima
# [438.10998535]
# Window:  165 Method:  auto_arima
# [440.375]
# Window:  166 Method:  auto_arima
# [440.92999268]
# Window:  167 Method:  auto_arima
# [439.95001221]
# Window:  168 Method:  auto_arima
# [443.1789856]
# Window:  169 Method:  auto_arima
# [441.45999146]
# Window:  170 Method:  auto_arima
# [441.20999146]
# Window:  171 Method:  auto_arima
# [442.73999023]
# Window:  172 Method:  auto_arima
# [441.26000977]
# Window:  173 Method:  auto_arima
# [441.79000854]
# Window:  174 Method:  auto_arima
# [442.72000122]
# Window:  175 Method:  auto_arima
# [445.95001221]
# Window:  176 Method:  auto_arima
# [446.85501099]
# Window:  177 Method:  auto_arima
# [448.32501221]
# Window:  178 Method:  auto_arima
# [448.26998901]
# Window:  179 Method:  auto_arima
# [448.38000488]
# Window:  180 Method:  auto_arima
# [449.17318726]
# Window:  181 Method:  auto_arima
# [449.16000366]
# Window:  182 Method:  auto_arima
# [449.27999878]
# Window:  183 Method:  auto_arima
# [450.48001099]
# Window:  184 Method:  auto_arima
# [451.33999634]
# Window:  185 Method:  auto_arima
# [450.92999268]
# Window:  186 Method:  auto_arima
# [450.12991333]
# Window:  187 Method:  auto_arima
# [450.89001465]
# Window:  188 Method:  auto_arima
# [451.]
# Window:  189 Method:  auto_arima
# [452.66000366]
# Window:  190 Method:  auto_arima
# [452.07998657]
# Window:  191 Method:  auto_arima
# [451.33999634]
# Window:  192 Method:  auto_arima
# [451.75500488]
# Window:  193 Method:  auto_arima
# [451.95999146]
# Window:  194 Method:  auto_arima
# [451.13500977]
# Window:  195 Method:  auto_arima
# [450.27999878]
# Window:  196 Method:  auto_arima
# [452.72970581]
# Window:  197 Method:  auto_arima
# [450.82998657]
# Window:  198 Method:  auto_arima
# [450.57998657]
# Window:  199 Method:  auto_arima
# [450.3500061]
# Window:  0 Method:  complex_smoothing
# <ipython-input-23-d1335f011bb4>:3: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   totalPredictions = pd.Series([])
# [454.64978027]
# Window:  1 Method:  complex_smoothing
# [454.93414307]
# Window:  2 Method:  complex_smoothing
# [455.30932617]
# Window:  3 Method:  complex_smoothing
# <ipython-input-23-d1335f011bb4>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outputFrame[modelName][predictionIndex] = prediction[0]
# [455.87329102]
# Window:  4 Method:  complex_smoothing
# [456.30053711]
# Window:  5 Method:  complex_smoothing
# [456.06542969]
# Window:  6 Method:  complex_smoothing
# [455.57925415]
# Window:  7 Method:  complex_smoothing
# [454.91189575]
# Window:  8 Method:  complex_smoothing
# [454.49023438]
# Window:  9 Method:  complex_smoothing
# [454.62649536]
# Window:  10 Method:  complex_smoothing
# [454.37835693]
# Window:  11 Method:  complex_smoothing
# [454.36837769]
# Window:  12 Method:  complex_smoothing
# [454.4979248]
# Window:  13 Method:  complex_smoothing
# [455.32791138]
# Window:  14 Method:  complex_smoothing
# [457.24700928]
# Window:  15 Method:  complex_smoothing
# [457.63848877]
# Window:  16 Method:  complex_smoothing
# [458.2545166]
# Window:  17 Method:  complex_smoothing
# [456.71246338]
# Window:  18 Method:  complex_smoothing
# [454.51095581]
# Window:  19 Method:  complex_smoothing
# [453.11264038]
# Window:  20 Method:  complex_smoothing
# [452.61392212]
# Window:  21 Method:  complex_smoothing
# [455.66415405]
# Window:  22 Method:  complex_smoothing
# [457.10671997]
# Window:  23 Method:  complex_smoothing
# [457.5189209]
# Window:  24 Method:  complex_smoothing
# [456.44769287]
# Window:  25 Method:  complex_smoothing
# [456.83822632]
# Window:  26 Method:  complex_smoothing
# [456.72219849]
# Window:  27 Method:  complex_smoothing
# [456.89346313]
# Window:  28 Method:  complex_smoothing
# [457.5602417]
# Window:  29 Method:  complex_smoothing
# [457.35742188]
# Window:  30 Method:  complex_smoothing
# [457.26098633]
# Window:  31 Method:  complex_smoothing
# [456.76855469]
# Window:  32 Method:  complex_smoothing
# [456.71902466]
# Window:  33 Method:  complex_smoothing
# [456.71432495]
# Window:  34 Method:  complex_smoothing
# [457.59576416]
# Window:  35 Method:  complex_smoothing
# [456.2857666]
# Window:  36 Method:  complex_smoothing
# [456.28131104]
# Window:  37 Method:  complex_smoothing
# [455.90917969]
# Window:  38 Method:  complex_smoothing
# [456.27160645]
# Window:  39 Method:  complex_smoothing
# [456.54440308]
# Window:  40 Method:  complex_smoothing
# [456.68029785]
# Window:  41 Method:  complex_smoothing
# [456.53451538]
# Window:  42 Method:  complex_smoothing
# [452.89266968]
# Window:  43 Method:  complex_smoothing
# [451.49185181]
# Window:  44 Method:  complex_smoothing
# [450.50698853]
# Window:  45 Method:  complex_smoothing
# [451.00671387]
# Window:  46 Method:  complex_smoothing
# [450.85513306]
# Window:  47 Method:  complex_smoothing
# [449.71520996]
# Window:  48 Method:  complex_smoothing
# [450.07202148]
# Window:  49 Method:  complex_smoothing
# [447.96548462]
# Window:  50 Method:  complex_smoothing
# [449.11254883]
# Window:  51 Method:  complex_smoothing
# [449.5758667]
# Window:  52 Method:  complex_smoothing
# [450.31546021]
# Window:  53 Method:  complex_smoothing
# [449.92822266]
# Window:  54 Method:  complex_smoothing
# [449.38632202]
# Window:  55 Method:  complex_smoothing
# [448.965271]
# Window:  56 Method:  complex_smoothing
# [450.15374756]
# Window:  57 Method:  complex_smoothing
# [451.2883606]
# Window:  58 Method:  complex_smoothing
# [452.2744751]
# Window:  59 Method:  complex_smoothing
# [451.80105591]
# Window:  60 Method:  complex_smoothing
# [448.92758179]
# Window:  61 Method:  complex_smoothing
# [447.48800659]
# Window:  62 Method:  complex_smoothing
# [446.96047974]
# Window:  63 Method:  complex_smoothing
# [449.11184692]
# Window:  64 Method:  complex_smoothing
# [448.79067993]
# Window:  65 Method:  complex_smoothing
# [449.43051147]
# Window:  66 Method:  complex_smoothing
# [449.61560059]
# Window:  67 Method:  complex_smoothing
# [449.63571167]
# Window:  68 Method:  complex_smoothing
# [449.74398804]
# Window:  69 Method:  complex_smoothing
# [450.54147339]
# Window:  70 Method:  complex_smoothing
# [447.07452393]
# Window:  71 Method:  complex_smoothing
# [446.38043213]
# Window:  72 Method:  complex_smoothing
# [446.4588623]
# Window:  73 Method:  complex_smoothing
# [446.85430908]
# Window:  74 Method:  complex_smoothing
# [447.51913452]
# Window:  75 Method:  complex_smoothing
# [448.37557983]
# Window:  76 Method:  complex_smoothing
# [448.69049072]
# Window:  77 Method:  complex_smoothing
# [448.52947998]
# Window:  78 Method:  complex_smoothing
# [446.53619385]
# Window:  79 Method:  complex_smoothing
# [446.09213257]
# Window:  80 Method:  complex_smoothing
# [447.16900635]
# Window:  81 Method:  complex_smoothing
# [448.25271606]
# Window:  82 Method:  complex_smoothing
# [447.90698242]
# Window:  83 Method:  complex_smoothing
# [446.20220947]
# Window:  84 Method:  complex_smoothing
# [450.01751709]
# Window:  85 Method:  complex_smoothing
# [449.08398438]
# Window:  86 Method:  complex_smoothing
# [447.32781982]
# Window:  87 Method:  complex_smoothing
# [446.3270874]
# Window:  88 Method:  complex_smoothing
# [446.41848755]
# Window:  89 Method:  complex_smoothing
# [446.27453613]
# Window:  90 Method:  complex_smoothing
# [446.00445557]
# Window:  91 Method:  complex_smoothing
# [446.05126953]
# Window:  92 Method:  complex_smoothing
# [444.887146]
# Window:  93 Method:  complex_smoothing
# [445.05148315]
# Window:  94 Method:  complex_smoothing
# [445.36734009]
# Window:  95 Method:  complex_smoothing
# [445.60699463]
# Window:  96 Method:  complex_smoothing
# [445.8309021]
# Window:  97 Method:  complex_smoothing
# [445.64364624]
# Window:  98 Method:  complex_smoothing
# [445.85415649]
# Window:  99 Method:  complex_smoothing
# [446.9052124]
# Window:  100 Method:  complex_smoothing
# [446.73144531]
# Window:  101 Method:  complex_smoothing
# [447.22406006]
# Window:  102 Method:  complex_smoothing
# [446.90734863]
# Window:  103 Method:  complex_smoothing
# [446.8795166]
# Window:  104 Method:  complex_smoothing
# [447.87142944]
# Window:  105 Method:  complex_smoothing
# [444.80291748]
# Window:  106 Method:  complex_smoothing
# [444.84912109]
# Window:  107 Method:  complex_smoothing
# [444.71844482]
# Window:  108 Method:  complex_smoothing
# [444.56744385]
# Window:  109 Method:  complex_smoothing
# [444.03097534]
# Window:  110 Method:  complex_smoothing
# [442.94494629]
# Window:  111 Method:  complex_smoothing
# [442.95217896]
# Window:  112 Method:  complex_smoothing
# [443.3230896]
# Window:  113 Method:  complex_smoothing
# [443.50112915]
# Window:  114 Method:  complex_smoothing
# [442.16656494]
# Window:  115 Method:  complex_smoothing
# [441.50006104]
# Window:  116 Method:  complex_smoothing
# [442.40792847]
# Window:  117 Method:  complex_smoothing
# [440.58712769]
# Window:  118 Method:  complex_smoothing
# [439.83059692]
# Window:  119 Method:  complex_smoothing
# [440.09555054]
# Window:  120 Method:  complex_smoothing
# [439.47640991]
# Window:  121 Method:  complex_smoothing
# [440.20056152]
# Window:  122 Method:  complex_smoothing
# [439.49758911]
# Window:  123 Method:  complex_smoothing
# [438.72439575]
# Window:  124 Method:  complex_smoothing
# [437.19485474]
# Window:  125 Method:  complex_smoothing
# [436.45422363]
# Window:  126 Method:  complex_smoothing
# [434.37796021]
# Window:  127 Method:  complex_smoothing
# [435.0942688]
# Window:  128 Method:  complex_smoothing
# [435.59057617]
# Window:  129 Method:  complex_smoothing
# [435.56530762]
# Window:  130 Method:  complex_smoothing
# [435.88406372]
# Window:  131 Method:  complex_smoothing
# [436.09576416]
# Window:  132 Method:  complex_smoothing
# [436.39538574]
# Window:  133 Method:  complex_smoothing
# [436.59838867]
# Window:  134 Method:  complex_smoothing
# [436.12313843]
# Window:  135 Method:  complex_smoothing
# [436.76095581]
# Window:  136 Method:  complex_smoothing
# [437.68133545]
# Window:  137 Method:  complex_smoothing
# [438.22418213]
# Window:  138 Method:  complex_smoothing
# [439.17486572]
# Window:  139 Method:  complex_smoothing
# [439.31622314]
# Window:  140 Method:  complex_smoothing
# [439.52853394]
# Window:  141 Method:  complex_smoothing
# [439.41110229]
# Window:  142 Method:  complex_smoothing
# [438.72329712]
# Window:  143 Method:  complex_smoothing
# [438.33776855]
# Window:  144 Method:  complex_smoothing
# [438.5406189]
# Window:  145 Method:  complex_smoothing
# [438.50924683]
# Window:  146 Method:  complex_smoothing
# [438.19094849]
# Window:  147 Method:  complex_smoothing
# [440.36743164]
# Window:  148 Method:  complex_smoothing
# [441.80459595]
# Window:  149 Method:  complex_smoothing
# [442.02905273]
# Window:  150 Method:  complex_smoothing
# [442.99353027]
# Window:  151 Method:  complex_smoothing
# [442.97845459]
# Window:  152 Method:  complex_smoothing
# [443.16696167]
# Window:  153 Method:  complex_smoothing
# [443.02932739]
# Window:  154 Method:  complex_smoothing
# [442.35223389]
# Window:  155 Method:  complex_smoothing
# [441.02355957]
# Window:  156 Method:  complex_smoothing
# [440.21414185]
# Window:  157 Method:  complex_smoothing
# [439.35617065]
# Window:  158 Method:  complex_smoothing
# [439.20315552]
# Window:  159 Method:  complex_smoothing
# [438.80172729]
# Window:  160 Method:  complex_smoothing
# [437.30426025]
# Window:  161 Method:  complex_smoothing
# [437.54119873]
# Window:  162 Method:  complex_smoothing
# [437.94134521]
# Window:  163 Method:  complex_smoothing
# [438.66134644]
# Window:  164 Method:  complex_smoothing
# [438.2286377]
# Window:  165 Method:  complex_smoothing
# [439.95504761]
# Window:  166 Method:  complex_smoothing
# [440.74609375]
# Window:  167 Method:  complex_smoothing
# [440.11816406]
# Window:  168 Method:  complex_smoothing
# [442.57763672]
# Window:  169 Method:  complex_smoothing
# [441.69448853]
# Window:  170 Method:  complex_smoothing
# [441.31719971]
# Window:  171 Method:  complex_smoothing
# [442.46777344]
# Window:  172 Method:  complex_smoothing
# [441.51193237]
# Window:  173 Method:  complex_smoothing
# [441.74490356]
# Window:  174 Method:  complex_smoothing
# [442.53723145]
# Window:  175 Method:  complex_smoothing
# [445.27954102]
# Window:  176 Method:  complex_smoothing
# [446.55395508]
# Window:  177 Method:  complex_smoothing
# [447.98498535]
# Window:  178 Method:  complex_smoothing
# [448.22775269]
# Window:  179 Method:  complex_smoothing
# [448.36422729]
# Window:  180 Method:  complex_smoothing
# [449.02764893]
# Window:  181 Method:  complex_smoothing
# [449.14733887]
# Window:  182 Method:  complex_smoothing
# [449.26904297]
# Window:  183 Method:  complex_smoothing
# [450.25375366]
# Window:  184 Method:  complex_smoothing
# [451.13873291]
# Window:  185 Method:  complex_smoothing
# [450.98764038]
# Window:  186 Method:  complex_smoothing
# [450.31747437]
# Window:  187 Method:  complex_smoothing
# [450.79122925]
# Window:  188 Method:  complex_smoothing
# [450.9743042]
# Window:  189 Method:  complex_smoothing
# [452.33959961]
# Window:  190 Method:  complex_smoothing
# [452.14923096]
# Window:  191 Method:  complex_smoothing
# [451.51663208]
# Window:  192 Method:  complex_smoothing
# [451.72357178]
# Window:  193 Method:  complex_smoothing
# [451.92822266]
# Window:  194 Method:  complex_smoothing
# [451.30999756]
# Window:  195 Method:  complex_smoothing
# [450.50134277]
# Window:  196 Method:  complex_smoothing
# [452.30090332]
# Window:  197 Method:  complex_smoothing
# [451.14031982]
# Window:  198 Method:  complex_smoothing
# [450.70755005]
# Window:  199 Method:  complex_smoothing
# [450.43780518]
# Window:  0 Method:  auto_ets
# <ipython-input-23-d1335f011bb4>:3: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   totalPredictions = pd.Series([])
# [454.74573676]
# Window:  1 Method:  auto_ets
# <ipython-input-23-d1335f011bb4>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outputFrame[modelName][predictionIndex] = prediction[0]
# [454.97620039]
# Window:  2 Method:  auto_ets
# [455.36867165]
# Window:  3 Method:  auto_ets
# [455.98012857]
# Window:  4 Method:  auto_ets
# [456.37365798]
# Window:  5 Method:  auto_ets
# [455.98625901]
# Window:  6 Method:  auto_ets
# [455.43882182]
# Window:  7 Method:  auto_ets
# [454.73130537]
# Window:  8 Method:  auto_ets
# [454.36582538]
# Window:  9 Method:  auto_ets
# [454.6307761]
# Window:  10 Method:  auto_ets
# [454.29536805]
# Window:  11 Method:  auto_ets
# [454.33929444]
# Window:  12 Method:  auto_ets
# [454.50239863]
# Window:  13 Method:  auto_ets
# [455.49416231]
# Window:  14 Method:  auto_ets
# [457.66536842]
# Window:  15 Method:  auto_ets
# [457.70724867]
# Window:  16 Method:  auto_ets
# [458.36979883]
# Window:  17 Method:  auto_ets
# [456.33289354]
# Window:  18 Method:  auto_ets
# [453.97030816]
# Window:  19 Method:  auto_ets
# [452.75772783]
# Window:  20 Method:  auto_ets
# [452.4690982]
# Window:  21 Method:  auto_ets
# [456.34374862]
# Window:  22 Method:  auto_ets
# [457.42515869]
# Window:  23 Method:  auto_ets
# [457.59337052]
# Window:  24 Method:  auto_ets
# [456.17079364]
# Window:  25 Method:  auto_ets
# [456.89958117]
# Window:  26 Method:  auto_ets
# [456.6692044]
# Window:  27 Method:  auto_ets
# [456.90668865]
# Window:  28 Method:  auto_ets
# [457.68881384]
# Window:  29 Method:  auto_ets
# [457.28567945]
# Window:  30 Method:  auto_ets
# [457.21104271]
# Window:  31 Method:  auto_ets
# [456.62694046]
# Window:  32 Method:  auto_ets
# [456.67925581]
# Window:  33 Method:  auto_ets
# [456.68491781]
# Window:  34 Method:  auto_ets
# [457.77465952]
# Window:  35 Method:  auto_ets
# [455.95659532]
# Window:  36 Method:  auto_ets
# [456.24905555]
# Window:  37 Method:  auto_ets
# [455.79671639]
# Window:  38 Method:  auto_ets
# [456.32728739]
# Window:  39 Method:  auto_ets
# [456.58130401]
# Window:  40 Method:  auto_ets
# [456.68844709]
# Window:  41 Method:  auto_ets
# [456.47312692]
# Window:  42 Method:  auto_ets
# [452.02333697]
# Window:  43 Method:  auto_ets
# [451.13224278]
# Window:  44 Method:  auto_ets
# [450.25154889]
# Window:  45 Method:  auto_ets
# [451.09838437]
# Window:  46 Method:  auto_ets
# [450.7991584]
# Window:  47 Method:  auto_ets
# [449.42877861]
# Window:  48 Method:  auto_ets
# [450.13036]
# Window:  49 Method:  auto_ets
# [447.45765544]
# Window:  50 Method:  auto_ets
# [449.3514149]
# Window:  51 Method:  auto_ets
# [449.66532141]
# Window:  52 Method:  auto_ets
# [450.46783422]
# Window:  53 Method:  auto_ets
# [449.81977336]
# Window:  54 Method:  auto_ets
# [449.23870449]
# Window:  55 Method:  auto_ets
# [448.84595695]
# Window:  56 Method:  auto_ets
# [450.40667549]
# Window:  57 Method:  auto_ets
# [451.53328355]
# Window:  58 Method:  auto_ets
# [452.4847314]
# Window:  59 Method:  auto_ets
# [451.67205459]
# Window:  60 Method:  auto_ets
# [448.23835783]
# Window:  61 Method:  auto_ets
# [447.12498597]
# Window:  62 Method:  auto_ets
# [446.81427486]
# Window:  63 Method:  auto_ets
# [449.59228854]
# Window:  64 Method:  auto_ets
# [448.70268623]
# Window:  65 Method:  auto_ets
# [449.55767475]
# Window:  66 Method:  auto_ets
# [449.63887494]
# Window:  67 Method:  auto_ets
# [449.62025735]
# Window:  68 Method:  auto_ets
# [449.74819796]
# Window:  69 Method:  auto_ets
# [450.70650348]
# Window:  70 Method:  auto_ets
# [446.25638553]
# Window:  71 Method:  auto_ets
# [446.1909783]
# Window:  72 Method:  auto_ets
# [446.45603683]
# Window:  73 Method:  auto_ets
# [446.92795661]
# Window:  74 Method:  auto_ets
# [447.65520125]
# Window:  75 Method:  auto_ets
# [448.5574923]
# Window:  76 Method:  auto_ets
# [448.74724544]
# Window:  77 Method:  auto_ets
# [448.47396826]
# Window:  78 Method:  auto_ets
# [446.05539064]
# Window:  79 Method:  auto_ets
# [445.96625166]
# Window:  80 Method:  auto_ets
# [447.39804958]
# Window:  81 Method:  auto_ets
# [448.48964078]
# Window:  82 Method:  auto_ets
# [447.80978641]
# Window:  83 Method:  auto_ets
# [445.78847683]
# Window:  84 Method:  auto_ets
# [450.87003386]
# Window:  85 Method:  auto_ets
# [448.86546065]
# Window:  86 Method:  auto_ets
# [446.90435961]
# Window:  87 Method:  auto_ets
# [446.07408321]
# Window:  88 Method:  auto_ets
# [446.41913446]
# Window:  89 Method:  auto_ets
# [446.2233229]
# Window:  90 Method:  auto_ets
# [445.92507284]
# Window:  91 Method:  auto_ets
# [446.04301273]
# Window:  92 Method:  auto_ets
# [444.60439087]
# Window:  93 Method:  auto_ets
# [445.06909049]
# Window:  94 Method:  auto_ets
# [445.42409976]
# Window:  95 Method:  auto_ets
# [445.64630543]
# Window:  96 Method:  auto_ets
# [445.86634265]
# Window:  97 Method:  auto_ets
# [445.58466228]
# Window:  98 Method:  auto_ets
# [445.88502877]
# Window:  99 Method:  auto_ets
# [447.12889163]
# Window:  100 Method:  auto_ets
# [446.67773119]
# Window:  101 Method:  auto_ets
# [447.31901204]
# Window:  102 Method:  auto_ets
# [446.81847363]
# Window:  103 Method:  auto_ets
# [446.85440271]
# Window:  104 Method:  auto_ets
# [448.07926906]
# Window:  105 Method:  auto_ets
# [444.09100008]
# Window:  106 Method:  auto_ets
# [444.8314817]
# Window:  107 Method:  auto_ets
# [444.67213094]
# Window:  108 Method:  auto_ets
# [444.51786424]
# Window:  109 Method:  auto_ets
# [443.89147083]
# Window:  110 Method:  auto_ets
# [442.682141]
# Window:  111 Method:  auto_ets
# [442.93515724]
# Window:  112 Method:  auto_ets
# [443.39163781]
# Window:  113 Method:  auto_ets
# [443.52751155]
# Window:  114 Method:  auto_ets
# [441.85070209]
# Window:  115 Method:  auto_ets
# [441.32935674]
# Window:  116 Method:  auto_ets
# [442.59679752]
# Window:  117 Method:  auto_ets
# [440.16569775]
# Window:  118 Method:  auto_ets
# [439.63984262]
# Window:  119 Method:  auto_ets
# [440.14054513]
# Window:  120 Method:  auto_ets
# [439.32538322]
# Window:  121 Method:  auto_ets
# [440.35030076]
# Window:  122 Method:  auto_ets
# [439.32952603]
# Window:  123 Method:  auto_ets
# [438.53498664]
# Window:  124 Method:  auto_ets
# [436.8341049]
# Window:  125 Method:  auto_ets
# [436.27048378]
# Window:  126 Method:  auto_ets
# [433.89351448]
# Window:  127 Method:  auto_ets
# [435.23972263]
# Window:  128 Method:  auto_ets
# [435.69636602]
# Window:  129 Method:  auto_ets
# [435.55269941]
# Window:  130 Method:  auto_ets
# [435.94753432]
# Window:  131 Method:  auto_ets
# [436.136449]
# Window:  132 Method:  auto_ets
# [436.45399792]
# Window:  133 Method:  auto_ets
# [436.63656874]
# Window:  134 Method:  auto_ets
# [436.00747913]
# Window:  135 Method:  auto_ets
# [436.8933451]
# Window:  136 Method:  auto_ets
# [437.88134489]
# Window:  137 Method:  auto_ets
# [438.339931]
# Window:  138 Method:  auto_ets
# [439.38063904]
# Window:  139 Method:  auto_ets
# [439.34073844]
# Window:  140 Method:  auto_ets
# [439.56582107]
# Window:  141 Method:  auto_ets
# [439.37357073]
# Window:  142 Method:  auto_ets
# [438.55531857]
# Window:  143 Method:  auto_ets
# [438.2358876]
# Window:  144 Method:  auto_ets
# [438.57370477]
# Window:  145 Method:  auto_ets
# [438.49151879]
# Window:  146 Method:  auto_ets
# [438.10715479]
# Window:  147 Method:  auto_ets
# [440.84825927]
# Window:  148 Method:  auto_ets
# [442.12711509]
# Window:  149 Method:  auto_ets
# [442.071013]
# Window:  150 Method:  auto_ets
# [443.19976742]
# Window:  151 Method:  auto_ets
# [442.96415149]
# Window:  152 Method:  auto_ets
# [443.19576879]
# Window:  153 Method:  auto_ets
# [442.98389367]
# Window:  154 Method:  auto_ets
# [442.1844469]
# Window:  155 Method:  auto_ets
# [440.70642405]
# Window:  156 Method:  auto_ets
# [440.01235914]
# Window:  157 Method:  auto_ets
# [439.145424]
# Window:  158 Method:  auto_ets
# [439.15327227]
# Window:  159 Method:  auto_ets
# [438.69809822]
# Window:  160 Method:  auto_ets
# [436.95070081]
# Window:  161 Method:  auto_ets
# [437.57883119]
# Window:  162 Method:  auto_ets
# [438.02211449]
# Window:  163 Method:  auto_ets
# [438.81618125]
# Window:  164 Method:  auto_ets
# [438.12232088]
# Window:  165 Method:  auto_ets
# [440.33542085]
# Window:  166 Method:  auto_ets
# [440.91970064]
# Window:  167 Method:  auto_ets
# [439.96697798]
# Window:  168 Method:  auto_ets
# [443.12125353]
# Window:  169 Method:  auto_ets
# [441.49091417]
# Window:  170 Method:  auto_ets
# [441.21528736]
# Window:  171 Method:  auto_ets
# [442.71157218]
# Window:  172 Method:  auto_ets
# [441.28723615]
# Window:  173 Method:  auto_ets
# [441.78036241]
# Window:  174 Method:  auto_ets
# [442.70195036]
# Window:  175 Method:  auto_ets
# [445.88956291]
# Window:  176 Method:  auto_ets
# [446.83728863]
# Window:  177 Method:  auto_ets
# [448.29827558]
# Window:  178 Method:  auto_ets
# [448.2704975]
# Window:  179 Method:  auto_ets
# [448.37803634]
# Window:  180 Method:  auto_ets
# [449.15889331]
# Window:  181 Method:  auto_ets
# [449.1599837]
# Window:  182 Method:  auto_ets
# [449.27784134]
# Window:  183 Method:  auto_ets
# [450.45840031]
# Window:  184 Method:  auto_ets
# [451.32436607]
# Window:  185 Method:  auto_ets
# [450.93694964]
# Window:  186 Method:  auto_ets
# [450.14422707]
# Window:  187 Method:  auto_ets
# [450.87686009]
# Window:  188 Method:  auto_ets
# [450.99782823]
# Window:  189 Method:  auto_ets
# [452.63068858]
# Window:  190 Method:  auto_ets
# [452.08987604]
# Window:  191 Method:  auto_ets
# [451.35347647]
# Window:  192 Method:  auto_ets
# [451.74778685]
# Window:  193 Method:  auto_ets
# [451.95617678]
# Window:  194 Method:  auto_ets
# [451.14977139]
# Window:  195 Method:  auto_ets
# [450.29533369]
# Window:  196 Method:  auto_ets
# [452.68563849]
# Window:  197 Method:  auto_ets
# [450.86543487]
# Window:  198 Method:  auto_ets
# [450.58529013]
# Window:  199 Method:  auto_ets
# [450.35439125]
# Window:  0 Method:  dyn_theta
# <ipython-input-23-d1335f011bb4>:3: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   totalPredictions = pd.Series([])
# [454.74908447]
# Window:  1 Method:  dyn_theta
# <ipython-input-23-d1335f011bb4>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outputFrame[modelName][predictionIndex] = prediction[0]
# [454.97769165]
# Window:  2 Method:  dyn_theta
# [455.37103271]
# Window:  3 Method:  dyn_theta
# [455.98379517]
# Window:  4 Method:  dyn_theta
# [456.3760376]
# Window:  5 Method:  dyn_theta
# [455.98397827]
# Window:  6 Method:  dyn_theta
# [455.43554688]
# Window:  7 Method:  dyn_theta
# [454.72714233]
# Window:  8 Method:  dyn_theta
# [454.36364746]
# Window:  9 Method:  dyn_theta
# [454.6322937]
# Window:  10 Method:  dyn_theta
# [454.29342651]
# Window:  11 Method:  dyn_theta
# [454.33953857]
# Window:  12 Method:  dyn_theta
# [454.50335693]
# Window:  13 Method:  dyn_theta
# [455.49993896]
# Window:  14 Method:  dyn_theta
# [457.67800903]
# Window:  15 Method:  dyn_theta
# [457.70758057]
# Window:  16 Method:  dyn_theta
# [458.37338257]
# Window:  17 Method:  dyn_theta
# [456.32070923]
# Window:  18 Method:  dyn_theta
# [453.9588623]
# Window:  19 Method:  dyn_theta
# [452.75216675]
# Window:  20 Method:  dyn_theta
# [452.46786499]
# Window:  21 Method:  dyn_theta
# [456.36068726]
# Window:  22 Method:  dyn_theta
# [457.42919922]
# Window:  23 Method:  dyn_theta
# [457.59402466]
# Window:  24 Method:  dyn_theta
# [456.16564941]
# Window:  25 Method:  dyn_theta
# [456.90255737]
# Window:  26 Method:  dyn_theta
# [456.66836548]
# Window:  27 Method:  dyn_theta
# [456.90759277]
# Window:  28 Method:  dyn_theta
# [457.69207764]
# Window:  29 Method:  dyn_theta
# [457.28411865]
# Window:  30 Method:  dyn_theta
# [457.21072388]
# Window:  31 Method:  dyn_theta
# [456.62463379]
# Window:  32 Method:  dyn_theta
# [456.67944336]
# Window:  33 Method:  dyn_theta
# [456.68493652]
# Window:  34 Method:  dyn_theta
# [457.77896118]
# Window:  35 Method:  dyn_theta
# [455.94848633]
# Window:  36 Method:  dyn_theta
# [456.25033569]
# Window:  37 Method:  dyn_theta
# [455.7946167]
# Window:  38 Method:  dyn_theta
# [456.32958984]
# Window:  39 Method:  dyn_theta
# [456.58242798]
# Window:  40 Method:  dyn_theta
# [456.68893433]
# Window:  41 Method:  dyn_theta
# [456.47219849]
# Window:  42 Method:  dyn_theta
# [452.00512695]
# Window:  43 Method:  dyn_theta
# [451.12893677]
# Window:  44 Method:  dyn_theta
# [450.24847412]
# Window:  45 Method:  dyn_theta
# [451.10137939]
# Window:  46 Method:  dyn_theta
# [450.79806519]
# Window:  47 Method:  dyn_theta
# [449.42388916]
# Window:  48 Method:  dyn_theta
# [450.13284302]
# Window:  49 Method:  dyn_theta
# [447.44714355]
# Window:  50 Method:  dyn_theta
# [449.36068726]
# Window:  51 Method:  dyn_theta
# [449.66693115]
# Window:  52 Method:  dyn_theta
# [450.47189331]
# Window:  53 Method:  dyn_theta
# [449.81671143]
# Window:  54 Method:  dyn_theta
# [449.23587036]
# Window:  55 Method:  dyn_theta
# [448.84396362]
# Window:  56 Method:  dyn_theta
# [450.41412354]
# Window:  57 Method:  dyn_theta
# [451.53863525]
# Window:  58 Method:  dyn_theta
# [452.48919678]
# Window:  59 Method:  dyn_theta
# [451.66830444]
# Window:  60 Method:  dyn_theta
# [448.22479248]
# Window:  61 Method:  dyn_theta
# [447.12103271]
# Window:  62 Method:  dyn_theta
# [446.81311035]
# Window:  63 Method:  dyn_theta
# [449.60183716]
# Window:  64 Method:  dyn_theta
# [448.6991272]
# Window:  65 Method:  dyn_theta
# [449.56130981]
# Window:  66 Method:  dyn_theta
# [449.63922119]
# Window:  67 Method:  dyn_theta
# [449.62017822]
# Window:  68 Method:  dyn_theta
# [449.74868774]
# Window:  69 Method:  dyn_theta
# [450.71029663]
# Window:  70 Method:  dyn_theta
# [446.23519897]
# Window:  71 Method:  dyn_theta
# [446.19046021]
# Window:  72 Method:  dyn_theta
# [446.45730591]
# Window:  73 Method:  dyn_theta
# [446.9302063]
# Window:  74 Method:  dyn_theta
# [447.65863037]
# Window:  75 Method:  dyn_theta
# [448.5614624]
# Window:  76 Method:  dyn_theta
# [448.74810791]
# Window:  77 Method:  dyn_theta
# [448.47277832]
# Window:  78 Method:  dyn_theta
# [446.04452515]
# Window:  79 Method:  dyn_theta
# [445.96578979]
# Window:  80 Method:  dyn_theta
# [447.40447998]
# Window:  81 Method:  dyn_theta
# [448.49398804]
# Window:  82 Method:  dyn_theta
# [447.80691528]
# Window:  83 Method:  dyn_theta
# [445.78048706]
# Window:  84 Method:  dyn_theta
# [450.89831543]
# Window:  85 Method:  dyn_theta
# [448.85067749]
# Window:  86 Method:  dyn_theta
# [446.89099121]
# Window:  87 Method:  dyn_theta
# [446.06829834]
# Window:  88 Method:  dyn_theta
# [446.42141724]
# Window:  89 Method:  dyn_theta
# [446.22201538]
# Window:  90 Method:  dyn_theta
# [445.92303467]
# Window:  91 Method:  dyn_theta
# [446.04379272]
# Window:  92 Method:  dyn_theta
# [444.59463501]
# Window:  93 Method:  dyn_theta
# [445.07199097]
# Window:  94 Method:  dyn_theta
# [445.42642212]
# Window:  95 Method:  dyn_theta
# [445.64776611]
# Window:  96 Method:  dyn_theta
# [445.86776733]
# Window:  97 Method:  dyn_theta
# [445.58285522]
# Window:  98 Method:  dyn_theta
# [445.88693237]
# Window:  99 Method:  dyn_theta
# [447.13735962]
# Window:  100 Method:  dyn_theta
# [446.67468262]
# Window:  101 Method:  dyn_theta
# [447.32342529]
# Window:  102 Method:  dyn_theta
# [446.81512451]
# Window:  103 Method:  dyn_theta
# [446.85461426]
# Window:  104 Method:  dyn_theta
# [448.08755493]
# Window:  105 Method:  dyn_theta
# [444.06066895]
# Window:  106 Method:  dyn_theta
# [444.8371582]
# Window:  107 Method:  dyn_theta
# [444.67086792]
# Window:  108 Method:  dyn_theta
# [444.51657104]
# Window:  109 Method:  dyn_theta
# [443.88638306]
# Window:  110 Method:  dyn_theta
# [442.67227173]
# Window:  111 Method:  dyn_theta
# [442.93710327]
# Window:  112 Method:  dyn_theta
# [443.39535522]
# Window:  113 Method:  dyn_theta
# [443.52865601]
# Window:  114 Method:  dyn_theta
# [441.83709717]
# Window:  115 Method:  dyn_theta
# [441.32516479]
# Window:  116 Method:  dyn_theta
# [442.60705566]
# Window:  117 Method:  dyn_theta
# [440.14486694]
# Window:  118 Method:  dyn_theta
# [439.63516235]
# Window:  119 Method:  dyn_theta
# [440.14483643]
# Window:  120 Method:  dyn_theta
# [439.31835938]
# Window:  121 Method:  dyn_theta
# [440.35946655]
# Window:  122 Method:  dyn_theta
# [439.32049561]
# Window:  123 Method:  dyn_theta
# [438.52798462]
# Window:  124 Method:  dyn_theta
# [436.8192749]
# Window:  125 Method:  dyn_theta
# [436.26559448]
# Window:  126 Method:  dyn_theta
# [433.87417603]
# Window:  127 Method:  dyn_theta
# [435.25109863]
# Window:  128 Method:  dyn_theta
# [435.70043945]
# Window:  129 Method:  dyn_theta
# [435.55148315]
# Window:  130 Method:  dyn_theta
# [435.95095825]
# Window:  131 Method:  dyn_theta
# [436.13812256]
# Window:  132 Method:  dyn_theta
# [436.45678711]
# Window:  133 Method:  dyn_theta
# [436.63818359]
# Window:  134 Method:  dyn_theta
# [436.00204468]
# Window:  135 Method:  dyn_theta
# [436.90090942]
# Window:  136 Method:  dyn_theta
# [437.89001465]
# Window:  137 Method:  dyn_theta
# [438.34393311]
# Window:  138 Method:  dyn_theta
# [439.38943481]
# Window:  139 Method:  dyn_theta
# [439.34048462]
# Window:  140 Method:  dyn_theta
# [439.56771851]
# Window:  141 Method:  dyn_theta
# [439.37197876]
# Window:  142 Method:  dyn_theta
# [438.5484314]
# Window:  143 Method:  dyn_theta
# [438.23318481]
# Window:  144 Method:  dyn_theta
# [438.57650757]
# Window:  145 Method:  dyn_theta
# [438.49084473]
# Window:  146 Method:  dyn_theta
# [438.10391235]
# Window:  147 Method:  dyn_theta
# [440.87203979]
# Window:  148 Method:  dyn_theta
# [442.13720703]
# Window:  149 Method:  dyn_theta
# [442.07067871]
# Window:  150 Method:  dyn_theta
# [443.20849609]
# Window:  151 Method:  dyn_theta
# [442.96237183]
# Window:  152 Method:  dyn_theta
# [443.19763184]
# Window:  153 Method:  dyn_theta
# [442.98217773]
# Window:  154 Method:  dyn_theta
# [442.1781311]
# Window:  155 Method:  dyn_theta
# [440.69497681]
# Window:  156 Method:  dyn_theta
# [440.00695801]
# Window:  157 Method:  dyn_theta
# [439.13876343]
# Window:  158 Method:  dyn_theta
# [439.15325928]
# Window:  159 Method:  dyn_theta
# [438.69464111]
# Window:  160 Method:  dyn_theta
# [436.93777466]
# Window:  161 Method:  dyn_theta
# [437.58346558]
# Window:  162 Method:  dyn_theta
# [438.02554321]
# Window:  163 Method:  dyn_theta
# [438.82192993]
# Window:  164 Method:  dyn_theta
# [438.11709595]
# Window:  165 Method:  dyn_theta
# [440.35241699]
# Window:  166 Method:  dyn_theta
# [440.92422485]
# Window:  167 Method:  dyn_theta
# [439.95974731]
# Window:  168 Method:  dyn_theta
# [443.14678955]
# Window:  169 Method:  dyn_theta
# [441.47686768]
# Window:  170 Method:  dyn_theta
# [441.21264648]
# Window:  171 Method:  dyn_theta
# [442.72473145]
# Window:  172 Method:  dyn_theta
# [441.2746582]
# Window:  173 Method:  dyn_theta
# [441.78485107]
# Window:  174 Method:  dyn_theta
# [442.71066284]
# Window:  175 Method:  dyn_theta
# [445.91763306]
# Window:  176 Method:  dyn_theta
# [446.84564209]
# Window:  177 Method:  dyn_theta
# [448.31021118]
# Window:  178 Method:  dyn_theta
# [448.27038574]
# Window:  179 Method:  dyn_theta
# [448.37890625]
# Window:  180 Method:  dyn_theta
# [449.16525269]
# Window:  181 Method:  dyn_theta
# [449.1600647]
# Window:  182 Method:  dyn_theta
# [449.27880859]
# Window:  183 Method:  dyn_theta
# [450.46798706]
# Window:  184 Method:  dyn_theta
# [451.33126831]
# Window:  185 Method:  dyn_theta
# [450.93399048]
# Window:  186 Method:  dyn_theta
# [450.13793945]
# Window:  187 Method:  dyn_theta
# [450.88250732]
# Window:  188 Method:  dyn_theta
# [450.99884033]
# Window:  189 Method:  dyn_theta
# [452.6434021]
# Window:  190 Method:  dyn_theta
# [452.08563232]
# Window:  191 Method:  dyn_theta
# [451.34744263]
# Window:  192 Method:  dyn_theta
# [451.75091553]
# Window:  193 Method:  dyn_theta
# [451.95788574]
# Window:  194 Method:  dyn_theta
# [451.14324951]
# Window:  195 Method:  dyn_theta
# [450.28863525]
# Window:  196 Method:  dyn_theta
# [452.70529175]
# Window:  197 Method:  dyn_theta
# [450.84875488]
# Window:  198 Method:  dyn_theta
# [450.58267212]
# Window:  199 Method:  dyn_theta
# [450.35232544]

# %%
print(testResultsDF)

plot1 = testResultsDF.iloc[0:test_out_size,:]

# get the index as a column for plotting
plot1 = plot1.reset_index()

plot1 = pd.melt(plot1, id_vars = ['index'], value_vars =  ['auto_arima', 'auto_ets', 'complex_smoothing', 'dyn_theta', 'Price'])

print(plot1)

sns.lineplot(plot1, x = 'index', y = 'value', hue = 'variable')
# Out:
#           Price  auto_arima   dyn_theta    auto_ets  complex_smoothing
# 0    454.980011  454.754700  454.749084  454.745737         454.649780
# 1    455.375000  454.980011  454.977692  454.976200         454.934143
# 2    455.989990  455.375000  455.371033  455.368672         455.309326
# 3    456.380005  455.989990  455.983795  455.980129         455.873291
# 4    455.980011  456.380005  456.376038  456.373658         456.300537
# ..          ...         ...         ...         ...                ...
# 330  429.410004    0.000000    0.000000    0.000000           0.000000
# 331  427.500000    0.000000    0.000000    0.000000           0.000000
# 332  426.260010    0.000000    0.000000    0.000000           0.000000
# 333  427.579987    0.000000    0.000000    0.000000           0.000000
# 334  427.410004    0.000000    0.000000    0.000000           0.000000
#
# [335 rows x 5 columns]
#      index    variable       value
# 0        0  auto_arima  454.754700
# 1        1  auto_arima  454.980011
# 2        2  auto_arima  455.375000
# 3        3  auto_arima  455.989990
# 4        4  auto_arima  456.380005
# ..     ...         ...         ...
# 995    195       Price  452.729706
# 996    196       Price  450.829987
# 997    197       Price  450.579987
# 998    198       Price  450.350006
# 999    199       Price  450.149902
#
# [1000 rows x 3 columns]
# <Axes: xlabel='index', ylabel='value'>

# %%
crossValidation(seriesTrain, tempTest, 4, testResultsDF, 'auto_arima', aaPredFunction)

crossValidation(seriesTrain, tempTest, 4, testResultsDF, 'complex_smoothing', cesPredFunction)

crossValidation(seriesTrain, tempTest, 4, testResultsDF, 'auto_ets', etsPredFunction)

crossValidation(seriesTrain, tempTest, 4, testResultsDF, 'dyn_theta', dotPredFunction)
# Out:
# <ipython-input-25-c8f032eaf659>:3: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   totalPredictions = pd.Series([])
# Window:  0 Method:  auto_arima
# [454.75469971 454.75469971 454.75469971 454.75469971]
# Window:  1 Method:  auto_arima
# [456.38000488 456.38000488 456.38000488 456.38000488]
# Window:  2 Method:  auto_arima
# [454.35998535 454.35998535 454.35998535 454.35998535]
# Window:  3 Method:  auto_arima
# [454.50500488 454.50500488 454.50500488 454.50500488]
# Window:  4 Method:  auto_arima
# [458.38009644 458.38009644 458.38009644 458.38009644]
# Window:  5 Method:  auto_arima
# [452.46499634 452.46499634 452.46499634 452.46499634]
# Window:  6 Method:  auto_arima
# [456.1512146 456.1512146 456.1512146 456.1512146]
# Window:  7 Method:  auto_arima
# [457.70001221 457.70001221 457.70001221 457.70001221]
# Window:  8 Method:  auto_arima
# [456.67999268 456.67999268 456.67999268 456.67999268]
# Window:  9 Method:  auto_arima
# [456.25338745 456.25338745 456.25338745 456.25338745]
# Window:  10 Method:  auto_arima
# [456.69000244 456.69000244 456.69000244 456.69000244]
# Window:  11 Method:  auto_arima
# [450.23959351 450.23959351 450.23959351 450.23959351]
# Window:  12 Method:  auto_arima
# [450.14001465 450.14001465 450.14001465 450.14001465]
# Window:  13 Method:  auto_arima
# [450.48001099 450.48001099 450.48001099 450.48001099]
# Window:  14 Method:  auto_arima
# [450.42999268 450.42999268 450.42999268 450.42999268]
# Window:  15 Method:  auto_arima
# [448.19000244 448.19000244 448.19000244 448.19000244]
# Window:  16 Method:  auto_arima
# [448.69000244 448.69000244 448.69000244 448.69000244]
# Window:  17 Method:  auto_arima
# [449.75 449.75 449.75 449.75]
# Window:  18 Method:  auto_arima
# [446.45999146 446.45999146 446.45999146 446.45999146]
# Window:  19 Method:  auto_arima
# [448.75 448.75 448.75 448.75]
# Window:  20 Method:  auto_arima
# [447.41900635 447.41900635 447.41900635 447.41900635]
# Window:  21 Method:  auto_arima
# [450.95001221 450.95001221 450.95001221 450.95001221]
# Window:  22 Method:  auto_arima
# [446.42498779 446.42498779 446.42498779 446.42498779]
# Window:  23 Method:  auto_arima
# [444.57998657 444.57998657 444.57998657 444.57998657]
# Window:  24 Method:  auto_arima
# [445.86999512 445.86999512 445.86999512 445.86999512]
# Window:  25 Method:  auto_arima
# [446.67001343 446.67001343 446.67001343 446.67001343]
# Window:  26 Method:  auto_arima
# [448.1000061 448.1000061 448.1000061 448.1000061]
# Window:  27 Method:  auto_arima
# [444.51501465 444.51501465 444.51501465 444.51501465]
# Window:  28 Method:  auto_arima
# [443.3999939 443.3999939 443.3999939 443.3999939]
# Window:  29 Method:  auto_arima
# [442.61999512 442.61999512 442.61999512 442.61999512]
# Window:  30 Method:  auto_arima
# [439.30999756 439.30999756 439.30999756 439.30999756]
# Window:  31 Method:  auto_arima
# [436.80200195 436.80200195 436.80200195 436.80200195]
# Window:  32 Method:  auto_arima
# [435.70498657 435.70498657 435.70498657 435.70498657]
# Window:  33 Method:  auto_arima
# [436.45999146 436.45999146 436.45999146 436.45999146]
# Window:  34 Method:  auto_arima
# [437.8999939 437.8999939 437.8999939 437.8999939]
# Window:  35 Method:  auto_arima
# [439.57000732 439.57000732 439.57000732 439.57000732]
# Window:  36 Method:  auto_arima
# [438.57998657 438.57998657 438.57998657 438.57998657]
# Window:  37 Method:  auto_arima
# [442.1499939 442.1499939 442.1499939 442.1499939]
# Window:  38 Method:  auto_arima
# [443.20001221 443.20001221 443.20001221 443.20001221]
# Window:  39 Method:  auto_arima
# [440. 440. 440. 440.]
# Window:  40 Method:  auto_arima
# [436.92001343 436.92001343 436.92001343 436.92001343]
# Window:  41 Method:  auto_arima
# [438.10998535 438.10998535 438.10998535 438.10998535]
# Window:  42 Method:  auto_arima
# [443.1789856 443.1789856 443.1789856 443.1789856]
# Window:  43 Method:  auto_arima
# [441.26000977 441.26000977 441.26000977 441.26000977]
# Window:  44 Method:  auto_arima
# [446.85501099 446.85501099 446.85501099 446.85501099]
# Window:  45 Method:  auto_arima
# [449.17318726 449.17318726 449.17318726 449.17318726]
# Window:  46 Method:  auto_arima
# [451.33999634 451.33999634 451.33999634 451.33999634]
# Window:  47 Method:  auto_arima
# [451. 451. 451. 451.]
# Window:  48 Method:  auto_arima
# [451.75500488 451.75500488 451.75500488 451.75500488]
# Window:  49 Method:  auto_arima
# [452.72970581 452.72970581 452.72970581 452.72970581]
# Window:  0 Method:  complex_smoothing
# [454.64978027 454.66998291 454.69055176 454.71084595]
# Window:  1 Method:  complex_smoothing
# <ipython-input-25-c8f032eaf659>:3: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   totalPredictions = pd.Series([])
# [456.30053711 456.3218689  456.34332275 456.36465454]
# Window:  2 Method:  complex_smoothing
# [454.49023438 454.51016235 454.53018188 454.55014038]
# Window:  3 Method:  complex_smoothing
# [454.4979248  454.51818848 454.53851318 454.55877686]
# Window:  4 Method:  complex_smoothing
# [458.2545166  458.27764893 458.30029297 458.32333374]
# Window:  5 Method:  complex_smoothing
# [452.61392212 452.63345337 452.65280151 452.67230225]
# Window:  6 Method:  complex_smoothing
# [456.44769287 456.4694519  456.49209595 456.51403809]
# Window:  7 Method:  complex_smoothing
# [457.5602417  457.5814209  457.60281372 457.62402344]
# Window:  8 Method:  complex_smoothing
# [456.71902466 456.740448   456.7618103  456.78323364]
# Window:  9 Method:  complex_smoothing
# [456.28131104 456.30371094 456.3253479  456.34759521]
# Window:  10 Method:  complex_smoothing
# [456.68029785 456.70065308 456.72058105 456.74084473]
# Window:  11 Method:  complex_smoothing
# [450.50698853 450.52349854 450.5406189  450.55725098]
# Window:  12 Method:  complex_smoothing
# [450.07202148 450.08895874 450.10583496 450.12277222]
# Window:  13 Method:  complex_smoothing
# [450.31546021 450.3326416  450.34902954 450.36605835]
# Window:  14 Method:  complex_smoothing
# [450.15374756 450.17111206 450.18765259 450.20483398]
# Window:  15 Method:  complex_smoothing
# [448.92758179 448.94311523 448.95916748 448.974823  ]
# Window:  16 Method:  complex_smoothing
# [448.79067993 448.80609131 448.82226562 448.83782959]
# Window:  17 Method:  complex_smoothing
# [449.74398804 449.76043701 449.7772522  449.79376221]
# Window:  18 Method:  complex_smoothing
# [446.4588623  446.47268677 446.48727417 446.50125122]
# Window:  19 Method:  complex_smoothing
# [448.69049072 448.70544434 448.72076416 448.73580933]
# Window:  20 Method:  complex_smoothing
# [447.16900635 447.18383789 447.19876099 447.21362305]
# Window:  21 Method:  complex_smoothing
# [450.01751709 450.03521729 450.05136108 450.0687561 ]
# Window:  22 Method:  complex_smoothing
# [446.41848755 446.43228149 446.44549561 446.45916748]
# Window:  23 Method:  complex_smoothing
# [444.887146   444.90023804 444.91348267 444.92660522]
# Window:  24 Method:  complex_smoothing
# [445.8309021  445.84436035 445.8578186  445.87127686]
# Window:  25 Method:  complex_smoothing
# [446.73144531 446.74557495 446.75994873 446.77410889]
# Window:  26 Method:  complex_smoothing
# [447.87142944 447.88668823 447.90188599 447.91714478]
# Window:  27 Method:  complex_smoothing
# [444.56744385 444.57992554 444.59197998 444.60437012]
# Window:  28 Method:  complex_smoothing
# [443.3230896  443.33563232 443.34802246 443.36053467]
# Window:  29 Method:  complex_smoothing
# [442.40792847 442.41976929 442.431427   442.4432373 ]
# Window:  30 Method:  complex_smoothing
# [439.47640991 439.48571777 439.49505615 439.50439453]
# Window:  31 Method:  complex_smoothing
# [437.19485474 437.20309448 437.2116394  437.21994019]
# Window:  32 Method:  complex_smoothing
# [435.59057617 435.59780884 435.60531616 435.61260986]
# Window:  33 Method:  complex_smoothing
# [436.39538574 436.40328979 436.41125488 436.41915894]
# Window:  34 Method:  complex_smoothing
# [437.68133545 437.69021606 437.6991272  437.70800781]
# Window:  35 Method:  complex_smoothing
# [439.52853394 439.53790283 439.54721069 439.55657959]
# Window:  36 Method:  complex_smoothing
# [438.5406189  438.54977417 438.55886841 438.56799316]
# Window:  37 Method:  complex_smoothing
# [441.80459595 441.81518555 441.8258667  441.8364563 ]
# Window:  38 Method:  complex_smoothing
# [443.16696167 443.17843628 443.18978882 443.20126343]
# Window:  39 Method:  complex_smoothing
# [440.21414185 440.22363281 440.23309326 440.24258423]
# Window:  40 Method:  complex_smoothing
# [437.30426025 437.31231689 437.32049561 437.32858276]
# Window:  41 Method:  complex_smoothing
# [438.2286377  438.23693848 438.24545288 438.2538147 ]
# Window:  42 Method:  complex_smoothing
# [442.57763672 442.58856201 442.59899902 442.60983276]
# Window:  43 Method:  complex_smoothing
# [441.51193237 441.52246094 441.53317261 441.54373169]
# Window:  44 Method:  complex_smoothing
# [446.55395508 446.56726074 446.58081055 446.59417725]
# Window:  45 Method:  complex_smoothing
# [449.02764893 449.04342651 449.05932617 449.07513428]
# Window:  46 Method:  complex_smoothing
# [451.13873291 451.15463257 451.17053223 451.18643188]
# Window:  47 Method:  complex_smoothing
# [450.9743042  450.99008179 451.006073   451.02191162]
# Window:  48 Method:  complex_smoothing
# [451.72357178 451.73950195 451.7555542  451.77151489]
# Window:  49 Method:  complex_smoothing
# [452.30090332 452.3180542  452.33456421 452.35159302]
# Window:  0 Method:  auto_ets
# <ipython-input-25-c8f032eaf659>:3: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   totalPredictions = pd.Series([])
# [454.74573676 454.74573676 454.74573676 454.74573676]
# Window:  1 Method:  auto_ets
# [456.37365798 456.37365798 456.37365798 456.37365798]
# Window:  2 Method:  auto_ets
# [454.36582538 454.36582538 454.36582538 454.36582538]
# Window:  3 Method:  auto_ets
# [454.50239863 454.50239863 454.50239863 454.50239863]
# Window:  4 Method:  auto_ets
# [458.36979883 458.36979883 458.36979883 458.36979883]
# Window:  5 Method:  auto_ets
# [452.4690982 452.4690982 452.4690982 452.4690982]
# Window:  6 Method:  auto_ets
# [456.17079364 456.17079364 456.17079364 456.17079364]
# Window:  7 Method:  auto_ets
# [457.68881384 457.68881384 457.68881384 457.68881384]
# Window:  8 Method:  auto_ets
# [456.67925581 456.67925581 456.67925581 456.67925581]
# Window:  9 Method:  auto_ets
# [456.24905555 456.24905555 456.24905555 456.24905555]
# Window:  10 Method:  auto_ets
# [456.68844709 456.68844709 456.68844709 456.68844709]
# Window:  11 Method:  auto_ets
# [450.25154889 450.25154889 450.25154889 450.25154889]
# Window:  12 Method:  auto_ets
# [450.13036 450.13036 450.13036 450.13036]
# Window:  13 Method:  auto_ets
# [450.46783422 450.46783422 450.46783422 450.46783422]
# Window:  14 Method:  auto_ets
# [450.40667549 450.40667549 450.40667549 450.40667549]
# Window:  15 Method:  auto_ets
# [448.23835783 448.23835783 448.23835783 448.23835783]
# Window:  16 Method:  auto_ets
# [448.70268623 448.70268623 448.70268623 448.70268623]
# Window:  17 Method:  auto_ets
# [449.74819796 449.74819796 449.74819796 449.74819796]
# Window:  18 Method:  auto_ets
# [446.45603683 446.45603683 446.45603683 446.45603683]
# Window:  19 Method:  auto_ets
# [448.74724544 448.74724544 448.74724544 448.74724544]
# Window:  20 Method:  auto_ets
# [447.39804958 447.39804958 447.39804958 447.39804958]
# Window:  21 Method:  auto_ets
# [450.87003386 450.87003386 450.87003386 450.87003386]
# Window:  22 Method:  auto_ets
# [446.41913446 446.41913446 446.41913446 446.41913446]
# Window:  23 Method:  auto_ets
# [444.60439087 444.60439087 444.60439087 444.60439087]
# Window:  24 Method:  auto_ets
# [445.86634265 445.86634265 445.86634265 445.86634265]
# Window:  25 Method:  auto_ets
# [446.67773119 446.67773119 446.67773119 446.67773119]
# Window:  26 Method:  auto_ets
# [448.07926906 448.07926906 448.07926906 448.07926906]
# Window:  27 Method:  auto_ets
# [444.51786424 444.51786424 444.51786424 444.51786424]
# Window:  28 Method:  auto_ets
# [443.39163781 443.39163781 443.39163781 443.39163781]
# Window:  29 Method:  auto_ets
# [442.59679752 442.59679752 442.59679752 442.59679752]
# Window:  30 Method:  auto_ets
# [439.32538322 439.32538322 439.32538322 439.32538322]
# Window:  31 Method:  auto_ets
# [436.8341049 436.8341049 436.8341049 436.8341049]
# Window:  32 Method:  auto_ets
# [435.69636602 435.69636602 435.69636602 435.69636602]
# Window:  33 Method:  auto_ets
# [436.45399792 436.45399792 436.45399792 436.45399792]
# Window:  34 Method:  auto_ets
# [437.88134489 437.88134489 437.88134489 437.88134489]
# Window:  35 Method:  auto_ets
# [439.56582107 439.56582107 439.56582107 439.56582107]
# Window:  36 Method:  auto_ets
# [438.57370477 438.57370477 438.57370477 438.57370477]
# Window:  37 Method:  auto_ets
# [442.12711509 442.12711509 442.12711509 442.12711509]
# Window:  38 Method:  auto_ets
# [443.19576879 443.19576879 443.19576879 443.19576879]
# Window:  39 Method:  auto_ets
# [440.01235914 440.01235914 440.01235914 440.01235914]
# Window:  40 Method:  auto_ets
# [436.95070081 436.95070081 436.95070081 436.95070081]
# Window:  41 Method:  auto_ets
# [438.12232088 438.12232088 438.12232088 438.12232088]
# Window:  42 Method:  auto_ets
# [443.12125353 443.12125353 443.12125353 443.12125353]
# Window:  43 Method:  auto_ets
# [441.28723615 441.28723615 441.28723615 441.28723615]
# Window:  44 Method:  auto_ets
# [446.83728863 446.83728863 446.83728863 446.83728863]
# Window:  45 Method:  auto_ets
# [449.15889331 449.15889331 449.15889331 449.15889331]
# Window:  46 Method:  auto_ets
# [451.32436607 451.32436607 451.32436607 451.32436607]
# Window:  47 Method:  auto_ets
# [450.99782823 450.99782823 450.99782823 450.99782823]
# Window:  48 Method:  auto_ets
# [451.74778685 451.74778685 451.74778685 451.74778685]
# Window:  49 Method:  auto_ets
# [452.68563849 452.68563849 452.68563849 452.68563849]
# Window:  0 Method:  dyn_theta
# <ipython-input-25-c8f032eaf659>:3: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   totalPredictions = pd.Series([])
# [454.74908447 454.74908447 454.74908447 454.74908447]
# Window:  1 Method:  dyn_theta
# [456.3760376 456.3760376 456.3760376 456.3760376]
# Window:  2 Method:  dyn_theta
# [454.36364746 454.36364746 454.36364746 454.36364746]
# Window:  3 Method:  dyn_theta
# [454.50335693 454.50335693 454.50335693 454.50335693]
# Window:  4 Method:  dyn_theta
# [458.37338257 458.37338257 458.37338257 458.37338257]
# Window:  5 Method:  dyn_theta
# [452.46786499 452.46786499 452.46786499 452.46786499]
# Window:  6 Method:  dyn_theta
# [456.16564941 456.16564941 456.16564941 456.16564941]
# Window:  7 Method:  dyn_theta
# [457.69207764 457.69207764 457.69207764 457.69207764]
# Window:  8 Method:  dyn_theta
# [456.67944336 456.67944336 456.67944336 456.67944336]
# Window:  9 Method:  dyn_theta
# [456.25033569 456.25033569 456.25033569 456.25033569]
# Window:  10 Method:  dyn_theta
# [456.68893433 456.68893433 456.68893433 456.68893433]
# Window:  11 Method:  dyn_theta
# [450.24847412 450.24847412 450.24847412 450.24847412]
# Window:  12 Method:  dyn_theta
# [450.13284302 450.13284302 450.13284302 450.13284302]
# Window:  13 Method:  dyn_theta
# [450.47189331 450.47189331 450.47189331 450.47189331]
# Window:  14 Method:  dyn_theta
# [450.41412354 450.41412354 450.41412354 450.41412354]
# Window:  15 Method:  dyn_theta
# [448.22479248 448.22479248 448.22479248 448.22479248]
# Window:  16 Method:  dyn_theta
# [448.6991272 448.6991272 448.6991272 448.6991272]
# Window:  17 Method:  dyn_theta
# [449.74868774 449.74868774 449.74868774 449.74868774]
# Window:  18 Method:  dyn_theta
# [446.45730591 446.45730591 446.45730591 446.45730591]
# Window:  19 Method:  dyn_theta
# [448.74810791 448.74810791 448.74810791 448.74810791]
# Window:  20 Method:  dyn_theta
# [447.40447998 447.40447998 447.40447998 447.40447998]
# Window:  21 Method:  dyn_theta
# [450.89831543 450.89831543 450.89831543 450.89831543]
# Window:  22 Method:  dyn_theta
# [446.42141724 446.42141724 446.42141724 446.42141724]
# Window:  23 Method:  dyn_theta
# [444.59463501 444.59463501 444.59463501 444.59463501]
# Window:  24 Method:  dyn_theta
# [445.86776733 445.86776733 445.86776733 445.86776733]
# Window:  25 Method:  dyn_theta
# [446.67468262 446.67468262 446.67468262 446.67468262]
# Window:  26 Method:  dyn_theta
# [448.08755493 448.08755493 448.08755493 448.08755493]
# Window:  27 Method:  dyn_theta
# [444.51657104 444.51657104 444.51657104 444.51657104]
# Window:  28 Method:  dyn_theta
# [443.39535522 443.39535522 443.39535522 443.39535522]
# Window:  29 Method:  dyn_theta
# [442.60705566 442.60705566 442.60705566 442.60705566]
# Window:  30 Method:  dyn_theta
# [439.31835938 439.31835938 439.31835938 439.31835938]
# Window:  31 Method:  dyn_theta
# [436.8192749 436.8192749 436.8192749 436.8192749]
# Window:  32 Method:  dyn_theta
# [435.70043945 435.70043945 435.70043945 435.70043945]
# Window:  33 Method:  dyn_theta
# [436.45678711 436.45678711 436.45678711 436.45678711]
# Window:  34 Method:  dyn_theta
# [437.89001465 437.89001465 437.89001465 437.89001465]
# Window:  35 Method:  dyn_theta
# [439.56771851 439.56771851 439.56771851 439.56771851]
# Window:  36 Method:  dyn_theta
# [438.57650757 438.57650757 438.57650757 438.57650757]
# Window:  37 Method:  dyn_theta
# [442.13720703 442.13720703 442.13720703 442.13720703]
# Window:  38 Method:  dyn_theta
# [443.19763184 443.19763184 443.19763184 443.19763184]
# Window:  39 Method:  dyn_theta
# [440.00695801 440.00695801 440.00695801 440.00695801]
# Window:  40 Method:  dyn_theta
# [436.93777466 436.93777466 436.93777466 436.93777466]
# Window:  41 Method:  dyn_theta
# [438.11709595 438.11709595 438.11709595 438.11709595]
# Window:  42 Method:  dyn_theta
# [443.14678955 443.14678955 443.14678955 443.14678955]
# Window:  43 Method:  dyn_theta
# [441.2746582 441.2746582 441.2746582 441.2746582]
# Window:  44 Method:  dyn_theta
# [446.84564209 446.84564209 446.84564209 446.84564209]
# Window:  45 Method:  dyn_theta
# [449.16525269 449.16525269 449.16525269 449.16525269]
# Window:  46 Method:  dyn_theta
# [451.33126831 451.33126831 451.33126831 451.33126831]
# Window:  47 Method:  dyn_theta
# [450.99884033 450.99884033 450.99884033 450.99884033]
# Window:  48 Method:  dyn_theta
# [451.75091553 451.75091553 451.75091553 451.75091553]
# Window:  49 Method:  dyn_theta
# [452.70529175 452.70529175 452.70529175 452.70529175]

# %%
plot1 = testResultsDF.iloc[0:test_out_size,:]

# get the index as a column for plotting
plot1 = plot1.reset_index()

plot1 = pd.melt(plot1, id_vars = ['index'], value_vars =  ['auto_arima', 'auto_ets', 'complex_smoothing', 'dyn_theta', 'Price'])

print(plot1)

sns.lineplot(plot1, x = 'index', y = 'value', hue = 'variable')
# Out:
#      index    variable       value
# 0        0  auto_arima  454.754700
# 1        1  auto_arima  454.754700
# 2        2  auto_arima  455.375000
# 3        3  auto_arima  455.375000
# 4        4  auto_arima  456.380005
# ..     ...         ...         ...
# 195     35       Price  456.253387
# 196     36       Price  455.790009
# 197     37       Price  456.334991
# 198     38       Price  456.584991
# 199     39       Price  456.690002
#
# [200 rows x 3 columns]
# <Axes: xlabel='index', ylabel='value'>

# %%
print(testResultsDF)

plot2 = testResultsDF.iloc[0:test_out_size,:]

plot2['auto_arima'] = plot2['auto_arima'] - plot2['Price']
plot2['auto_ets'] = plot2['auto_ets'] - plot2['Price']
plot2['complex_smoothing'] = plot2['complex_smoothing'] - plot2['Price']
plot2['dyn_theta'] = plot2['dyn_theta'] - plot2['Price']





# get the index as a column for plotting
plot2 = plot2.reset_index()

errorDat = plot2.copy()

plot2 = pd.melt(plot2, id_vars = ['index'], value_vars =  ['auto_arima', 'auto_ets', 'complex_smoothing', 'dyn_theta'])

sns.barplot(plot2, x = 'index', y = 'value', hue = 'variable')
# Out:
#           Price  auto_arima   dyn_theta    auto_ets  complex_smoothing
# 0    454.980011  454.754700  454.749084  454.745737         454.649780
# 1    455.375000  454.980011  454.977692  454.976200         454.934143
# 2    455.989990  455.375000  455.371033  455.368672         455.309326
# 3    456.380005  455.989990  455.983795  455.980129         455.873291
# 4    455.980011  456.380005  456.376038  456.373658         456.300537
# ..          ...         ...         ...         ...                ...
# 330  429.410004    0.000000    0.000000    0.000000           0.000000
# 331  427.500000    0.000000    0.000000    0.000000           0.000000
# 332  426.260010    0.000000    0.000000    0.000000           0.000000
# 333  427.579987    0.000000    0.000000    0.000000           0.000000
# 334  427.410004    0.000000    0.000000    0.000000           0.000000
#
# [335 rows x 5 columns]
# <ipython-input-34-130b33d266cc>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plot2['auto_arima'] = plot2['auto_arima'] - plot2['Price']
# <ipython-input-34-130b33d266cc>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plot2['auto_ets'] = plot2['auto_ets'] - plot2['Price']
# <ipython-input-34-130b33d266cc>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plot2['complex_smoothing'] = plot2['complex_smoothing'] - plot2['Price']
# <ipython-input-34-130b33d266cc>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plot2['dyn_theta'] = plot2['dyn_theta'] - plot2['Price']
# <Axes: xlabel='index', ylabel='value'>

# %%
errorDat['optimal'] = 0

for index in range(0, errorDat.shape[0]):
   # print(index)
    predictionErrors = errorDat.loc[:,('auto_arima', 'auto_ets', 'dyn_theta', 'complex_smoothing') ]

    #print(predictionErrors.min())

    errorDat.loc[index ,'optimal'] = min(predictionErrors)

errorDat
# Out:
#      index       Price  auto_arima  dyn_theta  auto_ets  complex_smoothing  \
# 0        0  454.980011   -0.225311  -0.230927 -0.234274          -0.330231
# 1        1  455.375000   -0.394989  -0.397308 -0.398800          -0.440857
# 2        2  455.989990   -0.614990  -0.618958 -0.621319          -0.680664
# 3        3  456.380005   -0.390015  -0.396210 -0.399876          -0.506714
# 4        4  455.980011    0.399994   0.396027  0.393647           0.320526
# ..     ...         ...         ...        ...       ...                ...
# 195    195  452.729706   -2.449707  -2.441071 -2.434372          -2.228363
# 196    196  450.829987    1.899719   1.875305  1.855652           1.470917
# 197    197  450.579987    0.250000   0.268768  0.285448           0.560333
# 198    198  450.350006    0.229980   0.232666  0.235284           0.357544
# 199    199  450.149902    0.200104   0.202423  0.204489           0.287903
#
#         optimal
# 0    auto_arima
# 1    auto_arima
# 2    auto_arima
# 3    auto_arima
# 4    auto_arima
# ..          ...
# 195  auto_arima
# 196  auto_arima
# 197  auto_arima
# 198  auto_arima
# 199  auto_arima
#
# [200 rows x 7 columns]

# %%
errorDat['optimal'].value_counts()
# Out:
# auto_arima    200
# Name: optimal, dtype: int64

# %%
# Getting more different financial datasets
"""
data = yf.download('SPY','2022-06-01','2023-09-30', interval ="60m")
data.reset_index(inplace = True)
train_size = 2000

data_train = data[:train_size]
data_test = data[train_size:]

test_size = len(data_test)


data_test = data_test[["Datetime", "Close"]]
data_train = data_train[["Datetime", "Close"]]

seriesTrain = data_train.set_index('Datetime')
seriesTest = data_test.set_index('Datetime')

testResultsDF = pd.DataFrame(index = range(test_size))
testResultsDF['Price'] = 0
# Get a clean format for close prices
for i in range(0,test_size):
    testResultsDF['Price'][i] = seriesTest.values[i][0]


# Initialize empty cells for the statistical forecasts
testResultsDF['auto_arima'] = 0
testResultsDF['dyn_theta'] = 0
testResultsDF['auto_ets'] = 0
testResultsDF['complex_smoothing'] = 0
"""

def prep_ticker(ticker, start_date = '2022-06-01', end_date = '2023-09-30', intervals = '60m', train_size = 2000, model_list = ['auto_arima', 'dyn_theta', 'auto_ets', 'complex_smoothing']):
  data = yf.download(ticker,start_date, end_date, interval = intervals)
  #print(data.head())
  data.reset_index(inplace = True)


  data_train = data[:train_size]
  data_test = data[train_size:]

  test_size = len(data_test)


  data_test = data_test[["Datetime", "Close"]]
  data_train = data_train[["Datetime", "Close"]]

  seriesTrain = data_train.set_index('Datetime')
  seriesTest = data_test.set_index('Datetime')

  testResultsDF = pd.DataFrame(index = range(test_size))
  testResultsDF['Price'] = 0

  #print(data.head())

  # Get a clean format for close prices
  for i in range(0,test_size):
      testResultsDF['Price'][i] = seriesTest.values[i][0]


  # Initialize empty cells for the statistical forecasts
  for modeltype in model_list:
    testResultsDF[modeltype] = 0

  return testResultsDF, seriesTrain, seriesTest

# %%
testResultsQQQ, trainSeriesQQQ, testSeriesQQQ = prep_ticker('QQQ')

print(testResultsQQQ.head() )
# Out:
# [*********************100%%**********************]  1 of 1 completed
#         Price  auto_arima  dyn_theta  auto_ets  complex_smoothing
# 0  376.239990           0          0         0                  0
# 1  377.880005           0          0         0                  0
# 2  378.390015           0          0         0                  0
# 3  378.799988           0          0         0                  0
# 4  379.730011           0          0         0                  0

# %%
def stat_test_wrapper(seriesTrain, seriesTest, testDF,  test_out_size = 200, window_size = 1):
    # Set the number of observations to be included in the test set

  testDFCopy = testDF.copy()

  tempTest = seriesTest[:test_out_size]

  # Auto Arima
  crossValidation(seriesTrain, tempTest, window_size, testDFCopy, 'auto_arima', aaPredFunction)

  crossValidation(seriesTrain, tempTest, window_size, testDFCopy, 'complex_smoothing', cesPredFunction)

  crossValidation(seriesTrain, tempTest, window_size, testDFCopy, 'auto_ets', etsPredFunction)

  crossValidation(seriesTrain, tempTest, window_size, testDFCopy, 'dyn_theta', dotPredFunction)




  plot2 = testDFCopy.iloc[0:test_out_size,:]

  plot2.loc[:,'auto_arima'] = abs( plot2.loc[:,'auto_arima'] - plot2.loc[:,'Price'] )
  plot2.loc[:,'auto_ets'] = abs( plot2.loc[:,'auto_ets'] - plot2.loc[:,'Price'] )
  plot2.loc[:,'complex_smoothing'] = abs( plot2.loc[:,'complex_smoothing'] - plot2.loc[:,'Price'] )
  plot2.loc[:,'dyn_theta'] = abs( plot2.loc[:,'dyn_theta'] - plot2.loc[:,'Price'] )

  # get the index as a column for plotting
  plot2 = plot2.reset_index()

  errorDat = plot2.copy()

  names = ['auto_arima', 'auto_ets', 'dyn_theta', 'complex_smoothing']
  errorDat['optimal'] = errorDat[names].idxmin(axis="columns")

  #print("reached loop")
  """
  for index in range(0, errorDat.shape[0]):
      #print(index)

      predictionErrors = errorDat.loc[index,['auto_arima', 'auto_ets', 'dyn_theta', 'complex_smoothing'] ]

      #print(predictionErrors)

      #print(min(abs(predictionErrors)))
      #errorDat.loc[index ,'optimal'] = min(abs(predictionErrors))
  """



  return testDFCopy, errorDat

# %%
testResultsQQQ, trainSeriesQQQ, testSeriesQQQ = prep_ticker('QQQ')

# %%
qqqpreds, qqqerrors = stat_test_wrapper(trainSeriesQQQ, testSeriesQQQ, testResultsQQQ, 200, 100)

# %%
print(qqqerrors.head())
print(qqqerrors['optimal'].value_counts() )
# QQQ, 22-6-1 to 23-9-30, 1hr,
# > 5-1 is auto_arima 4, complex smoothing 1
# > 100-1 is auto_arima 50, complex smoothing 44, dyn_theta 6
# > 200-20 is auto_arima 41, complex_smoothing 111, dyn_theta 48
# > 200-50 is auto_arima 18, c_s 92, dyn_theta 90
# > 200-100 is a_a 60, c_s 78, d_t 62
# AAPL, 22-6-1 to 23-9-30, 1hr,
# 100 - 1 is a_a 42, c_s 51, d_t 7
# Out:
#    index       Price  auto_arima  dyn_theta  auto_ets  complex_smoothing  \
# 0      0  376.239990    0.859985   0.847839  0.859863           0.588776
# 1      1  377.880005    2.500000   2.487854  2.499878           2.191284
# 2      2  378.390015    3.010010   2.997864  3.009888           2.661804
# 3      3  378.799988    3.419983   3.407837  3.419861           3.033875
# 4      4  379.730011    4.350006   4.337860  4.349884           3.924713
#
#              optimal
# 0  complex_smoothing
# 1  complex_smoothing
# 2  complex_smoothing
# 3  complex_smoothing
# 4  complex_smoothing
# complex_smoothing    78
# dyn_theta            62
# auto_arima           60
# Name: optimal, dtype: int64

# %%
testResultsAAPL, trainSeriesAAPL, testSeriesAAPL = prep_ticker('AAPL')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
AAPLpreds, AAPLerrors = stat_test_wrapper(trainSeriesAAPL, testSeriesAAPL, testResultsAAPL, 100, 1)

# %%
print(AAPLerrors.head())
print(AAPLerrors['optimal'].value_counts() )

print(AAPLerrors['optimal'])
# Out:
#    index       Price  auto_arima  dyn_theta  auto_ets  complex_smoothing  \
# 0      0  192.735001    0.365005   0.356277  0.362233           0.168747
# 1      1  193.395004    0.660004   0.663559  0.661329           0.671524
# 2      2  193.820007    0.425003   0.431641  0.427100           0.534119
# 3      3  193.764694    0.055313   0.050995  0.053959           0.027710
# 4      4  194.199997    0.435303   0.434799  0.435132           0.415909
#
#              optimal
# 0  complex_smoothing
# 1         auto_arima
# 2         auto_arima
# 3  complex_smoothing
# 4  complex_smoothing
# complex_smoothing    51
# auto_arima           42
# dyn_theta             7
# Name: optimal, dtype: int64
# 0     complex_smoothing
# 1            auto_arima
# 2            auto_arima
# 3     complex_smoothing
# 4     complex_smoothing
#             ...
# 95    complex_smoothing
# 96           auto_arima
# 97    complex_smoothing
# 98           auto_arima
# 99    complex_smoothing
# Name: optimal, Length: 100, dtype: object
